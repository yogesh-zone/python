# %%
import pandas as pd
pd.Series?

# %%
# panda stores series values in a typed array using the Numpy library.
# This offers significant speed-up when processing data versus traditional python lists.
animals = ['Tiger', 'Bear', 'Moose']
numbers = [1, 2, 3]
pd.Series(animals)  , pd.Series(numbers)
# Out:
# (0    Tiger
#  1     Bear
#  2    Moose
#  dtype: object,
#  0    1
#  1    2
#  2    3
#  dtype: int64)

# %%
import numpy as np
# NaN is not None , and you can directly compare with NaN, 

print(np.nan == None)

print(np.nan == np.nan)

# use np.isnan instead to compare nan
print(np.isnan(np.nan))
# Out:
# False
# False
# True

# %% [markdown]
# # Create from Dictionary

# %%
 sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
print(s,"\n")

# You could also separate your index creation from the data by passing in the index as a list explicitly to the series
s = pd.Series( ['Tiger', 'Bear', 'Moose'], index= ['India', 'America', 'Canada'] )
print(s)
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object
#
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %% [markdown]
# # Querying a Series  iloc, loc

# %%
#  A panda.Series can be queried, either by the index position or the index label.
#  -> To query by numeric location, starting at zero, use the iloc attribute.
#  -> To query by the index label, you can use the loc attribute.
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
print(s,"\n")

# iloc by index position
print(s.iloc[3],"\n")

# loc by index label
print(s.loc['Golf'])

# s[index] -> Pandas can't determine automatically whether you're intending to query by index position or index label
# And the safer option is to be more explicit and use the iloc or loc attributes directly
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object
#
# South Korea
#
# Scotland

# %% [markdown]
# # working with series

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])  
total = np.sum(s)  #-> it will sum all the elm in series
total
# Out:
# 324.0

# %%
s = pd.Series(np.random.randint(0,9,5))    # 1: start from  #2: end before  #3: how many numbers   
s.head()  # will show up default (first 5 elm in s)  # custome  s.head(val)
s.tail()  # will show up default (last 5 elm in s)  # custome  s.tail(val)
# Out:
# 0    3
# 1    0
# 2    6
# 3    5
# 4    5
# dtype: int32

# %%
print(s)
s+=2 #adds two to each item in s using broadcasting
s
# Out:
# 0    3
# 1    0
# 2    6
# 3    5
# 4    5
# dtype: int32
# 0    5
# 1    2
# 2    8
# 3    7
# 4    7
# dtype: int32

# %%
''' 
If the value you pass in as the index doesn't exist, then a new entry is added. And keep in mind, indices can have mixed types
While it's important to be aware of the typing going on underneath,Pandas will automatically change the underlying NumPy types
as appropriate. 
'''

s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %% [markdown]
# # The DataFrame Data Structure

# %%
'''
The DataFrame is conceptually a two-dimensional series object
 -> there's an index and multiple columns of content, with each column having a label
 -> We can think of the DataFrame itself as simply a two-axes labeled array.
'''

purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 1', 'Cost']   #1: which lvl rows       #2:  which column
df.iloc[0:2,2:3]            #1  row from till end+1  #2: column start and end
# Out:
#          Cost
# Store 1  22.5
# Store 1   2.5

# %%
# What if we just wanted to do column selection and just get a list of all of the costs?
df.T  # (transpose) swaps all of the columns and rows.This works, but it's pretty ugly.
df.T.loc['Cost']

# or we can use iloc and fetch all rows and only cost column
df.iloc[:,2:3]

# or we can use loc and can call any row and column we want
df.loc[:,['Name','Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %% [markdown]
# # let's talk about dropping data

# %%
'''
It's easy to delete data in series and DataFrames, and we can use the drop function to do so
The drop function doesn't change the DataFrame by default. And instead, returns to you a copyof the DataFrame
with the given rows removed.
'''
df_copy = df.drop('Store 1') # won't change df
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df_copy 
# to change it in place we can use  df = df.drop('Store 1')

# deleting a column 
del df_copy['Cost']

# df_copy

# add a column 
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %% [markdown]
# # Dataframe Indexing and Loading

# %%
'''
The common work flow is to read your data into a DataFrame then reduce this DataFrame to the particular columns or rows
that you're interested in working with.
'''

# // read csv
df = pd.read_csv('./csvFiles/olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('./csvFiles/olympics.csv', index_col = 0, skiprows=1) #index_col which col to skip  #skiprows how many rows to skip
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %%
df.columns

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True)

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)               0         2               2
# Algeria (ALG)                   2         8              15
# Argentina (ARG)                24        28              70
# Armenia (ARM)                   2         9              12
# Australasia (ANZ) [ANZ]         4         5              12

# %% [markdown]
# # Querying a DataFrame

# %%
# // first step, create a boolean mask
df['Gold'] > 0

# then , use `where` function to apply boolean mask to dataframe
only_gold = df.where(df['Gold'] > 0)   # or   
only_gold = df[df['Gold'] > 0]
only_gold.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                   5         2         8              15
# Argentina (ARG)                18        24        28              70
# Armenia (ARM)                   1         2         9              12
# Australasia (ANZ) [ANZ]         3         4         5              12
# Australia (AUS) [AUS] [Z]     144       155       181             480

# %%
only_gold['Gold'].count()  , df['Gold'].count()
# it means there are 47 nations didn't got gold in olympics
# Out:
# (100, 147)

# %% [markdown]
# # Drop Data

# %%
# Often we want to drop those rows which have no data. 
only_gold = only_gold.dropna()
only_gold
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# ...                             ...   ...     ...     ...    ...       ...
# Venezuela (VEN)                  17     2       2       8     12         4
# Yugoslavia (YUG) [YUG]           16    26      29      28     83        14
# Zimbabwe (ZIM) [ZIM]             12     3       4       1      8         1
# Mixed team (ZZX) [ZZX]            3     8       5       4     17         0
# Totals                           27  4809    4775    5130  14714        22
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
# ...                           ...       ...       ...      ...      ...
# Venezuela (VEN)                 0         0         0        0       21
# Yugoslavia (YUG) [YUG]          0         3         1        4       30
# Zimbabwe (ZIM) [ZIM]            0         0         0        0       13
# Mixed team (ZZX) [ZZX]          0         0         0        0        3
# Totals                        959       958       948     2865       49
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                   5         2         8              15
# Argentina (ARG)                18        24        28              70
# Armenia (ARM)                   1         2         9              12
# Australasia (ANZ) [ANZ]         3         4         5              12
# Australia (AUS) [AUS] [Z]     144       155       181             480
# ...                           ...       ...       ...             ...
# Venezuela (VEN)                 2         2         8              12
# Yugoslavia (YUG) [YUG]         26        32        29              87
# Zimbabwe (ZIM) [ZIM]            3         4         1               8
# Mixed team (ZZX) [ZZX]          8         5         4              17
# Totals                       5768      5733      6078           17579
#
# [100 rows x 15 columns]

# %%
# total country who won gold atleast once in total rounds
len(df[(df['Gold'] > 0) | (df['Gold.1'] > 0)])

# total country who won gold in 2 round but not in first
df[(df['Gold.1'] > 0) & (df['Gold'] == 0)]
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %% [markdown]
# # Indexing Dataframes

# %%
df['country'] = df.index  
df = df.set_index('Gold')
df.head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# 5               Algeria (ALG)
# 18            Argentina (ARG)
# 1               Armenia (ARM)
# 3     Australasia (ANZ) [ANZ]

# %% [markdown]
# # Group by

# %%
census_df = pd.read_csv("./csvFiles/census.csv")
df = census_df.groupby('STNAME')

#the first entries in all the groups formed.
df.first()
# Out:
#                       SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME
# Alabama                   40       3         6      1       0
# Alaska                    40       4         9      2       0
# Arizona                   40       4         8      4       0
# Arkansas                  40       3         7      5       0
# California                40       4         9      6       0
# Colorado                  40       4         8      8       0
# Connecticut               40       1         1      9       0
# Delaware                  40       3         5     10       0
# District of Columbia      40       3         5     11       0
# Florida                   40       3         5     12       0
# Georgia                   40       3         5     13       0
# Hawaii                    40       4         9     15       0
# Idaho                     40       4         8     16       0
# Illinois                  40       2         3     17       0
# Indiana                   40       2         3     18       0
# Iowa                      40       2         4     19       0
# Kansas                    40       2         4     20       0
# Kentucky                  40       3         6     21       0
# Louisiana                 40       3         7     22       0
# Maine                     40       1         1     23       0
# Maryland                  40       3         5     24       0
# Massachusetts             40       1         1     25       0
# Michigan                  40       2         3     26       0
# Minnesota                 40       2         4     27       0
# North Carolina           5.849442     6.331622
# North Dakota            14.782061    15.675696
# Ohio                     0.175060    -0.913728
# Oklahoma                 2.921241     3.970249
# Oregon                   7.779997    10.733510
# Pennsylvania             0.170229    -0.442643
# Rhode Island             1.332218     0.032209
# South Carolina           9.465643    10.772926
# South Dakota             2.460888    -0.098144
# Tennessee                5.222361     4.908398
# Texas                    9.780487     9.978697
# Utah                     2.069019     5.300638
# Vermont                 -0.937877    -2.089704
# Virginia                 2.315622     1.793779
# Washington               7.840731     9.653974
# West Virginia           -1.516045    -1.808887
# Wisconsin               -0.164130    -1.213969
# Wyoming                 -3.727831    -2.091573
#
# [51 rows x 99 columns]

# %%
# Finding particular group by get_group
df.get_group('Alabama')
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0       40       3         6      1       0  Alabama            Alabama
# 1       50       3         6      1       1  Alabama     Autauga County
# 2       50       3         6      1       3  Alabama     Baldwin County
# 3       50       3         6      1       5  Alabama     Barbour County
# 4       50       3         6      1       7  Alabama        Bibb County
# ..     ...     ...       ...    ...     ...      ...                ...
# 63      50       3         6      1     125  Alabama  Tuscaloosa County
# 64      50       3         6      1     127  Alabama      Walker County
# 65      50       3         6      1     129  Alabama  Washington County
# 66      50       3         6      1     131  Alabama      Wilcox County
# 67      50       3         6      1     133  Alabama     Winston County
#
#     CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0         4779736            4780127          4785161  ...          0.002295
# 1           54571              54571            54660  ...          7.242091
# 2          182265             182265           183193  ...         14.832960
# 3           27457              27457            27341  ...         -4.728132
# 4           22915              22919            22861  ...         -5.527043
# ..            ...                ...              ...  ...               ...
# 63         194656             194653           194977  ...          3.983504
# 64          67023              67023            67004  ...         -4.579296
# 65          17581              17583            17610  ...        -14.708407
# 66          11670              11665            11557  ...         -7.029724
# 67          24484              24483            24401  ...          0.410332
#
#     RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0          -0.193196          0.381066          0.582002         -0.467369
# 1          -2.915927         -3.012349          2.265971         -2.530799
# 2          17.647293         21.845705         19.243287         17.197872
# 3          -2.500690         -7.056824         -3.904217        -10.543299
# 4          -5.068871         -6.201001         -0.177537          0.177258
# ..               ...               ...               ...               ...
# 63          4.256278          5.261075          4.787490          1.884402
# 64         -4.336533         -0.666096         -3.300481         -3.087245
# 65        -13.062030        -11.181733          1.067236         -0.950486
# 66        -10.239356        -12.314507        -13.835235          0.090453
# 67         -3.916234          2.441548          1.077609         -6.669724
#
#     RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0      1.030015     0.826644     1.383282     1.724718     0.712594
# 1      7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2     15.844176    18.559627    22.727626    20.317142    18.293499
# 3     -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4     -5.088389    -4.363636    -5.403729     0.754533     1.107861
# ..          ...          ...          ...          ...          ...
# 63     5.306232     5.202679     6.333332     6.057539     3.158710
# 64    -4.085450    -3.869753    -0.181663    -2.692097    -2.460626
# 65   -13.849940   -12.075121   -10.122411     2.193763     0.118811
# 66    -7.029724   -10.239356   -12.314507   -13.835235     0.090453
# 67     0.410332    -3.957457     2.400166     1.036162    -6.711409
#
# [68 rows x 100 columns]

# %%
# group by more then one column for splitting
df = census_df.groupby(['STNAME','CTYNAME'])
df.first()
# Out:
#                          SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Alabama              40       3         6      1       0
#         Autauga County       50       3         6      1       1
#         Baldwin County       50       3         6      1       3
#         Barbour County       50       3         6      1       5
#         Bibb County          50       3         6      1       7
# ...                         ...     ...       ...    ...     ...
# Wyoming Teton County         50       4         8     56      39
#         Uinta County         50       4         8     56      41
#         Washakie County      50       4         8     56      43
#         Weston County        50       4         8     56      45
#         Wyoming              40       4         8     56       0
#
#                          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama                4779736            4780127          4785161
#         Autauga County           54571              54571            54660
#         Baldwin County          182265             182265           183193
#         Barbour County           27457              27457            27341
#         Bibb County              22915              22919            22861
# ...                                ...                ...              ...
# Wyoming Teton County             21294              21294            21297
#         Uinta County             21118              21118            21102
#         Washakie County           8533               8533             8545
#         Weston County             7208               7208             7181
#         Wyoming                 563626             563767           564516
#
#                          POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                            ...
# Alabama Alabama                  4801108          4816089  ...
#         Autauga County             55253            55175  ...
#         Baldwin County            186659           190396  ...
#         Barbour County             27226            27159  ...
#         Bibb County                22733            22642  ...
# ...                                  ...              ...  ...
# Wyoming Teton County               21482            21697  ...
#         Uinta County               20912            20989  ...
#         Washakie County             8469             8443  ...
#         Weston County               7114             7065  ...
#         Wyoming                   567768           577080  ...
#
#                          RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME  CTYNAME
# Alabama Alabama                  0.002295         -0.193196          0.381066
#         Autauga County           7.242091         -2.915927         -3.012349
#         Baldwin County          14.832960         17.647293         21.845705
#         Barbour County          -4.728132         -2.500690         -7.056824
#         Bibb County             -5.527043         -5.068871         -6.201001
# ...                                   ...               ...               ...
# Wyoming Teton County            -1.589565          0.972695         19.525929
#         Uinta County           -17.755986         -4.916350         -6.902954
#         Washakie County        -11.637475         -0.827815         -2.013502
#         Weston County          -11.752361         -8.040059         12.372583
#         Wyoming                 -0.381530          9.636214          4.487115
#
#                          RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# STNAME  CTYNAME
# Alabama Alabama                  0.582002         -0.467369     1.030015
#         Autauga County           2.265971         -2.530799     7.606016
#         Baldwin County          19.243287         17.197872    15.844176
#         Barbour County          -3.904217        -10.543299    -4.874741
#         Bibb County             -0.177537          0.177258    -5.088389
# ...                                   ...               ...          ...
# Wyoming Teton County            14.143021         -0.564849     0.654527
#         Uinta County           -14.215862        -12.127022   -18.136812
#         Washakie County        -17.781491          1.682288   -11.990126
#         Weston County            1.533635          6.935294   -12.032179
#         Wyoming                 -4.788275         -3.221091     0.289680
#
#                          RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME
# Alabama Alabama             0.826644     1.383282     1.724718     0.712594
#         Autauga County     -2.626146    -2.722002     2.592270    -2.187333
#         Baldwin County     18.559627    22.727626    20.317142    18.293499
#         Barbour County     -2.758113    -7.167664    -3.978583   -10.543299
#         Bibb County        -4.363636    -5.403729     0.754533     1.107861
# ...                              ...          ...          ...          ...
# Wyoming Teton County        2.408578    21.160658    16.308671     1.520747
#         Uinta County       -5.536861    -7.521840   -14.740608   -12.606351
#         Washakie County    -1.182592    -2.250385   -18.020168     1.441961
#         Weston County      -8.040059    12.372583     1.533635     6.935294
#         Wyoming            10.694870     5.440390    -3.727831    -2.091573
#
# [3192 rows x 98 columns]
